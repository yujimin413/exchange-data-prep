# %%
import pandas as pd
from sqlalchemy import create_engine

# CSV 파일 불러오기
df = pd.read_csv("school_info_refined_0504.csv")  

# 컬럼명 매핑 (한글 → 영문)
df.columns = [
    "program_type", "institution", "id", "region", "country",
    "korean_name", "english_name", "credit_requirement", "language_requirement",
    "notes", "available_courses", "website", "special_notes",
    "language_region", "available_majors"
]

# 불필요한 image 컬럼은 없으므로 따로 제외할 필요 없음

# SQLAlchemy 엔진 생성 (DB 접속정보 수정)
engine = create_engine("mysql+pymysql://shinhodeung10:tlsghemd1234@shinhodeung.cpm6oaem01lq.ap-northeast-2.rds.amazonaws.com:3306/exchange_db?charset=utf8mb4")


# university 테이블에 INSERT
# df.to_sql("university", con=engine, if_exists='append', index=False)

# %%
import pandas as pd
from sqlalchemy import create_engine, text

# CSV 파일 불러오기
df2 = pd.read_csv("reports_cleaned_final.csv")

# 컬럼명 재정의
df2.columns = [
    "index", "before_departure", "after_arrival", "campus_life", "university_intro",
    "impression", "file_name", "department", "student_id", "year",
    "name", "university", "program_type", "study_period"
]
df2 = df2.drop(columns=["index"])

# DB 연결
engine = create_engine("mysql+pymysql://shinhodeung10:tlsghemd1234@shinhodeung.cpm6oaem01lq.ap-northeast-2.rds.amazonaws.com:3306/exchange_db?charset=utf8mb4")

# report 테이블 생성
with engine.connect() as conn:
    conn.execute(text("""
        CREATE TABLE report (
            id INT NOT NULL AUTO_INCREMENT PRIMARY KEY,
            before_departure TEXT,
            after_arrival TEXT,
            campus_life TEXT,
            university_intro TEXT,
            impression TEXT,
            file_name VARCHAR(255),
            department VARCHAR(255),
            student_id VARCHAR(50),
            year VARCHAR(10),
            name VARCHAR(50),
            university VARCHAR(255),
            program_type VARCHAR(50),
            study_period VARCHAR(50)
        ) CHARACTER SET utf8mb4 COLLATE utf8mb4_unicode_ci;
    """))
    print("✅ report 테이블이 성공적으로 생성되었습니다.")

# 데이터 삽입
df2.to_sql("report", con=engine, if_exists='append', index=False)
print("📦 데이터 삽입 완료.")
# Out:
# ✅ report 테이블이 성공적으로 생성되었습니다.
# 📦 데이터 삽입 완료.
