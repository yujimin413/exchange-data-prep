# %%
import pandas as pd
from sqlalchemy import create_engine

# CSV 파일 불러오기
df = pd.read_csv("school_info_refined_0504.csv")  

# 컬럼명 매핑 (한글 → 영문)
df.columns = [
    "program_type", "institution", "id", "region", "country",
    "korean_name", "english_name", "credit_requirement", "language_requirement",
    "notes", "available_courses", "website", "special_notes",
    "language_region", "available_majors"
]

# 불필요한 image 컬럼은 없으므로 따로 제외할 필요 없음

# SQLAlchemy 엔진 생성 (DB 접속정보 수정)
engine = create_engine("mysql+pymysql://shinhodeung10:tlsghemd1234@shinhodeung.cpm6oaem01lq.ap-northeast-2.rds.amazonaws.com:3306/exchange_db?charset=utf8mb4")


# university 테이블에 INSERT
# df.to_sql("university", con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1933, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1932     if not evt_handled:
# -> 1933         self.dialect.do_executemany(
#    1934             cursor,
#    1935             str_statement,
#    1936             effective_parameters,
#    1937             context,
#    1938         )
#    1939 elif not effective_parameters and context.no_parameters:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:172, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
#     171 def do_executemany(self, cursor, statement, parameters, context=None):
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

# CSV 파일 불러오기
df2 = pd.read_csv("reports.csv")

# 컬럼명 매핑
df2.columns = [
    "index", "before_departure", "after_arrival", "campus_life", "university_intro",
    "impression", "file_name", "department", "student_id", "year",
    "name", "university", "program_type", "study_period"
]

df2 = df2.drop(columns=["index"])  # index 컬럼 제거

# SQLAlchemy 엔진 생성
engine = create_engine("mysql+pymysql://shinhodeung10:tlsghemd1234@shinhodeung.cpm6oaem01lq.ap-northeast-2.rds.amazonaws.com:3306/exchange_db?charset=utf8mb4")

# DB에 insert (append)
df2.to_sql("reports", con=engine, if_exists='append', index=False)
# Out:
# 770
